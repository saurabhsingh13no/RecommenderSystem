# %% [markdown]
# #  <center> Exploratory Data Analysis </center>

# %% [markdown]
# ## Importing necessary modules for data analysis

# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import pickle

# %% [markdown]
# ## 1) Importing events dataset

# %%
# Reading event datasets 
events = pd.read_csv("../data/events.csv")
events.head()
# Out:
#        timestamp  visitorid event  itemid  transactionid
# 0  1433221332117     257597  view  355908            NaN
# 1  1433224214164     992329  view  248676            NaN
# 2  1433221999827     111016  view  318965            NaN
# 3  1433221955914     483717  view  253185            NaN
# 4  1433221337106     951259  view  367447            NaN

# %%
# Describing quantitative features of events dataset
print ("No. of rows in events dataset : {0}".format(len(events)))
events.describe()
# Out:
# No. of rows in events dataset : 2756101
#           timestamp     visitorid        itemid  transactionid
# count  2.756101e+06  2.756101e+06  2.756101e+06   22457.000000
# mean   1.436424e+12  7.019229e+05  2.349225e+05    8826.497796
# std    3.366312e+09  4.056875e+05  1.341954e+05    5098.996290
# min    1.430622e+12  0.000000e+00  3.000000e+00       0.000000
# 25%    1.433478e+12  3.505660e+05  1.181200e+05    4411.000000
# 50%    1.436453e+12  7.020600e+05  2.360670e+05    8813.000000
# 75%    1.439225e+12  1.053437e+06  3.507150e+05   13224.000000
# max    1.442545e+12  1.407579e+06  4.668670e+05   17671.000000

# %%
# statistics for categorical variables
events.describe(include=[np.object])
# Out:
#           event
# count   2756101
# unique        3
# top        view
# freq    2664312

# %% [markdown]
# ## 2) Importing item_properites dataset

# %%
item_prop = pd.read_csv("../data/item_properties_part1.csv")
print ("No. of rows in item_prop : {0}".format(len(item_prop)))
item_prop.head()
# Out:
# No. of rows in item_prop : 10999999
#        timestamp  itemid    property                            value
# 0  1435460400000  460429  categoryid                             1338
# 1  1441508400000  206783         888          1116713 960601 n277.200
# 2  1439089200000  395014         400  n552.000 639502 n720.000 424566
# 3  1431226800000   59481         790                       n15360.000
# 4  1431831600000  156781         917                           828513

# %% [markdown]
# ## 3) Formatting property feature to numeric type

# %%
# replace categoryid with 0, and available with 1
def preProcessDF(item_prop):
    item_prop['property'] = item_prop['property'].replace(["categoryid"], 0)
    item_prop['property'] = item_prop['property'].replace(["available"], 1)
    item_prop['property'] = pd.to_numeric(item_prop.property.values)
    return item_prop

item_prop = preProcessDF(item_prop.copy())
item_prop.head()
# Out:
#        timestamp  itemid  property                            value
# 0  1435460400000  460429         0                             1338
# 1  1441508400000  206783       888          1116713 960601 n277.200
# 2  1439089200000  395014       400  n552.000 639502 n720.000 424566
# 3  1431226800000   59481       790                       n15360.000
# 4  1431831600000  156781       917                           828513

# %% [markdown]
# ## 4) Vectorizing itemid feature from item_prop dataFrame

# %%
def getDictOfItemIdVector(item_prop):
    """
    Given   : item_prop as pandas dataframe
    Return  : dictionary of ItemIdVector of all unique items in the product catalog
    """
    dictOfItemIdVector = defaultdict(set)
    for index, row in item_prop.iterrows():
        dictOfItemIdVector[row['itemid']].add(row['property'])
        
    return dictOfItemIdVector
    
def writeDictToFile(dictToFile, filename):
    with open(filename, 'wb') as handle:
        pickle.dump(dictToFile, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
def readDictFromFile(filename):
    with open(filename, 'rb') as handle:
        dictToFile = pickle.load(handle)
    return dictToFile
    
    
# dictOfItemIdVector = getDictOfItemIdVector(item_prop)
# dictOfItemIdVector = defaultdict(list, ((k, list(v)) for k, v in dictOfItemIdVector.items()))
# dictOfItemIdVector2  = dictOfItemIdVector.copy()
# writeDictToFile(dictOfItemIdVector, "../output/dictOfItemVector2.pickle")


# read dict from file
dictOfItemIdVector = readDictFromFile("../output/dictOfItemVector.pickle")

# %% [markdown]
# ## 5) Compute Cosine similarity of 2 vectors

# %%
def square_rooted(x):
 
    return round(np.sqrt(np.sum(np.dot(x,x))),3)
 
def cosine_similarity(x,y):
 
    numerator = np.sum(a*b for a,b in zip(x,y))
    denominator = square_rooted(x)*square_rooted(y)
    return round(numerator/float(denominator),3)

cosine_similarity(dictOfItemIdVector[0], dictOfItemIdVector[0])
# Out:
# 1.0

# %% [markdown]
# ## 6) Build userDict from events DF

# %%
def getDictOfUser(events):
    """
    Given   : events as pandas dataframe
    Return  : dictionary of all users- This can be treated as userProfiles
    """
    userDict = defaultdict(lambda : defaultdict(list))
    for index, row in events.iterrows():
        if row['event']=='view':
            userDict[row['visitorid']]['view'].append(row['itemid'])
        if row['event']=='addtocart':
            userDict[row['visitorid']]['addtocart'].append(row['itemid'])
            
    return userDict.copy()

userDict = getDictOfUser(events)

# %%
userDict
# Out:
# defaultdict(<function __main__.getDictOfUser.<locals>.<lambda>>,
#             {0: defaultdict(list, {'view': [285930, 357564, 67045]}),
#              1: defaultdict(list, {'view': [72028]}),
#              2: defaultdict(list,
#                          {'view': [216305,
#                            325215,
#                            342816,
#                            325215,
#                            342816,
#                            259884,
#                            216305,
#                            325215]}),
#              3: defaultdict(list, {'view': [385090]}),
#              4: defaultdict(list, {'view': [177677]}),
#              5: defaultdict(list, {'view': [61396]}),
#              6: defaultdict(list,
#                          {'addtocart': [65273],
#                           'view': [344723, 344723, 253615, 344723, 344723]}),
#              7: defaultdict(list, {'view': [164941, 139394, 226353]}),
#              8: defaultdict(list, {'view': [434230]}),
#              9: defaultdict(list, {'view': [222422]}),
#              10: defaultdict(list, {'view': [248766]}),
#              11: defaultdict(list, {'view': [448220]}),
#              12: defaultdict(list, {'view': [70225]}),
#              13: defaultdict(list, {'view': [320589, 278689]}),
#              14: defaultdict(list, {'view': [330269]}),
#              15: defaultdict(list, {'view': [22495]}),
#              16: defaultdict(list, {'view': [382645]}),
#              17: defaultdict(list, {'view': [138434]}),
#              18: defaultdict(list, {'view': [209302]}),
#              19: defaultdict(list, {'view': [84663]}),
#              20: defaultdict(list, {'view': [176623]}),
#              21: defaultdict(list, {'view': [76091]}),
#              22: defaultdict(list, {'view': [86411, 86411]}),
#              23: defaultdict(list, {'view': [44608, 283916, 283916]}),
#              24: defaultdict(list, {'view': [449369, 346051]}),
#              25: defaultdict(list, {'view': [344325]}),
#              26: defaultdict(list, {'view': [164342]}),
#              27: defaultdict(list, {'view': [314714]}),
#              28: defaultdict(list, {'view': [295343]}),
#              29: defaultdict(list, {'view': [299118]}),
#              30: defaultdict(list, {'view': [425758]}),
#              31: defaultdict(list, {'view': [465565]}),
#              32: defaultdict(list, {'view': [465465, 282491]}),
#              33: defaultdict(list, {'view': [185254]}),
#              34: defaultdict(list, {'view': [199885]}),
#              35: defaultdict(list, {'view': [187946]}),
#              36: defaultdict(list, {'view': [176286, 176286]}),
#              37: defaultdict(list,
#                          {'view': [168952,
#                            168952,
#                            168952,
#                            168952,
#                            168952,
#                            434344,
#                            168952,
#                            168952]}),
#              38: defaultdict(list, {'view': [182101]}),
#              39: defaultdict(list, {'view': [76740, 76740]}),
#              40: defaultdict(list, {'view': [164625]}),
#              41: defaultdict(list, {'view': [28961]}),
#              42: defaultdict(list, {'view': [60399]}),
#              43: defaultdict(list, {'view': [434782]}),
#              44: defaultdict(list, {'view': [11729]}),
#              45: defaultdict(list, {'view': [451993]}),
#              46: defaultdict(list, {'view': [3780, 3780]}),
#              47: defaultdict(list, {'view': [161925]}),
#              48: defaultdict(list, {'view': [215123]}),
#              49: defaultdict(list, {'view': [156173]}),
#              50: defaultdict(list, {'view': [331168]}),
#              51: defaultdict(list,
#                          {'view': [49967,
#                            429304,
#                            198762,
#                            358388,
#                            279059,
#                            198762]}),
#              52: defaultdict(list, {'view': [108504]}),
#              53: defaultdict(list, {'view': [217218]}),
#              54: defaultdict(list,
#                          {'view': [283115,
#                            283115,
#                            442228,
#                            442228,
#                            319680,
#                            388096,
#                            388096,
#                            319680,
#                            38965,
#                            249114,
#                            38965]}),
#              55: defaultdict(list, {'view': [399556, 399556]}),
#              56: defaultdict(list, {'view': [261455]}),
#              57: defaultdict(list, {'view': [152379]}),
#              58: defaultdict(list, {'view': [31406, 31406]}),
#              59: defaultdict(list, {'view': [5411]}),
#              60: defaultdict(list, {'view': [321706, 453279, 257070]}),
#              61: defaultdict(list, {'view': [6924]}),
#              62: defaultdict(list, {'view': [294847, 294847]}),
#              63: defaultdict(list, {'view': [61303]}),
#              64: defaultdict(list,
#                          {'view': [295653,
#                            233200,
#                            224700,
#                            160984,
#                            141657,
#                            118401,
#                            160984]}),
#              65: defaultdict(list, {'view': [52383, 353515, 52383, 168656]}),
#              66: defaultdict(list, {'view': [47930]}),
#              67: defaultdict(list, {'view': [451104]}),
#              68: defaultdict(list, {'view': [60701]}),
#              69: defaultdict(list, {'view': [59556]}),
#              70: defaultdict(list, {'view': [237208]}),
#              71: defaultdict(list, {'view': [436751]}),
#              72: defaultdict(list, {'view': [408846]}),
#              73: defaultdict(list, {'view': [80517, 80517]}),
#              74: defaultdict(list,
#                          {'view': [57171,
#                            57171,
#                            45410,
#                            59574,
#                            57171,
#                            262125,
#                            55826]}),
#              75: defaultdict(list,
#                          {'view': [257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            96883,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575,
#                            257575]}),
#              76: defaultdict(list, {'view': [278966, 278966, 420028]}),
#              77: defaultdict(list, {'view': [441880]}),
#              78: defaultdict(list, {'view': [140513]}),
#              79: defaultdict(list, {'view': [450209]}),
#              80: defaultdict(list, {'view': [458747]}),
#              81: defaultdict(list, {'view': [337512, 337512]}),
#              82: defaultdict(list, {'view': [85863]}),
#              83: defaultdict(list, {'view': [20095]}),
#              84: defaultdict(list, {'view': [371827]}),
#              85: defaultdict(list, {'view': [230005]}),
#              86: defaultdict(list, {'view': [150060, 150060]}),
#              87: defaultdict(list, {'view': [458733]}),
#              88: defaultdict(list, {'view': [58827, 420028]}),
#              89: defaultdict(list, {'view': [72435, 277742, 26210]}),
#              90: defaultdict(list, {'view': [89143]}),
#              91: defaultdict(list, {'view': [79513, 146100]}),
#              92: defaultdict(list, {'view': [359197]}),
#              93: defaultdict(list, {'view': [434480]}),
#              94: defaultdict(list, {'view': [347105, 129302, 129302]}),
#              95: defaultdict(list, {'view': [169956, 45520]}),
#              96: defaultdict(list, {'view': [447174]}),
#              97: defaultdict(list,
#                          {'view': [291964,
#                            400946,
#                            400946,
#                            400946,
#                            280039,
#                            291964,
#                            400946,
#                            280039]}),
#              98: defaultdict(list, {'view': [124764]}),
#              99: defaultdict(list, {'view': [158848, 158848]}),
#              100: defaultdict(list, {'view': [36054, 36054, 36054, 36054]}),
#              101: defaultdict(list, {'view': [275948]}),
#              102: defaultdict(list, {'view': [237539, 82955]}),
#              103: defaultdict(list, {'view': [311356, 123118]}),
#              104: defaultdict(list, {'view': [120522]}),
#              105: defaultdict(list, {'view': [66752, 66752]}),
#              106: defaultdict(list, {'view': [237756]}),
#              107: defaultdict(list, {'view': [459752]}),
#              108: defaultdict(list, {'view': [311484, 311484, 311484]}),
#              109: defaultdict(list, {'view': [216019]}),
#              110: defaultdict(list, {'view': [224322]}),
#              111: defaultdict(list, {'view': [169811, 169811]}),
#              112: defaultdict(list, {'view': [200802]}),
#              113: defaultdict(list, {'view': [164498]}),
#              114: defaultdict(list, {'view': [265338]}),
#              115: defaultdict(list, {'view': [428921]}),
#              116: defaultdict(list, {'view': [115584]}),
#              117: defaultdict(list, {'view': [280939, 257723]}),
#              118: defaultdict(list, {'view': [165280]}),
#              119: defaultdict(list, {'view': [393111]}),
#              120: defaultdict(list, {'view': [153339]}),
#              121: defaultdict(list, {'view': [43398]}),
#              122: defaultdict(list, {'view': [301278]}),
#              123: defaultdict(list, {'view': [356005]}),
#              124: defaultdict(list, {'view': [212357, 354724]}),
#              125: defaultdict(list, {'view': [9468]}),
#              126: defaultdict(list, {'view': [52901]}),
#              127: defaultdict(list, {'view': [164344]}),
#              128: defaultdict(list, {'view': [394678]}),
#              129: defaultdict(list, {'view': [436137]}),
#              130: defaultdict(list, {'view': [242425]}),
#              131: defaultdict(list, {'view': [351747]}),
#              132: defaultdict(list, {'view': [200128, 200128]}),
#              133: defaultdict(list, {'view': [2680]}),
#              134: defaultdict(list, {'view': [258549]}),
#              135: defaultdict(list, {'view': [21886]}),
#              136: defaultdict(list, {'view': [352001]}),
#              137: defaultdict(list, {'view': [383819]}),
#              138: defaultdict(list, {'view': [364123]}),
#              139: defaultdict(list, {'view': [111210]}),
#              140: defaultdict(list, {'view': [315911]}),
#              141: defaultdict(list, {'view': [369723]}),
#              142: defaultdict(list, {'view': [101094, 101094]}),
#              143: defaultdict(list, {'view': [321063]}),
#              144: defaultdict(list, {'view': [362964]}),
#              145: defaultdict(list, {'view': [274898]}),
#              146: defaultdict(list, {'view': [413203]}),
#              147: defaultdict(list, {'view': [426635]}),
#              148: defaultdict(list, {'view': [59467]}),
#              149: defaultdict(list, {'view': [332620, 332620]}),
#              150: defaultdict(list,
#                          {'addtocart': [452955],
#                           'view': [452955, 452955, 186933]}),
#              151: defaultdict(list, {'view': [48731]}),
#              152: defaultdict(list, {'view': [30990]}),
#              153: defaultdict(list, {'view': [322972]}),
#              154: defaultdict(list, {'view': [235849]}),
#              155: defaultdict(list,
#                          {'addtocart': [452082,
#                            368372,
#                            224623,
#                            389974,
#                            442601,
#                            41882,
#                            181405],
#                           'view': [134620,
#                            123027,
#                            134620,
#                            50928,
#                            373637,
#                            151670,
#                            143373]}),
#              156: defaultdict(list, {'view': [31611]}),
#              157: defaultdict(list, {'view': [226758]}),
#              158: defaultdict(list, {'view': [191726, 275959]}),
#              159: defaultdict(list, {'view': [224725]}),
#              160: defaultdict(list, {'view': [211839]}),
#              161: defaultdict(list, {'view': [337381]}),
#              162: defaultdict(list,
#                          {'view': [1152, 305656, 390093, 248862, 156142]}),
#              163: defaultdict(list, {'view': [189381, 17477]}),
#              164: defaultdict(list, {'view': [106828, 446506]}),
#              165: defaultdict(list, {'view': [39601, 39601]}),
#              166: defaultdict(list, {'view': [5374]}),
#              167: defaultdict(list, {'view': [120658]}),
#              168: defaultdict(list, {'view': [107195]}),
#              169: defaultdict(list, {'view': [312427, 84310, 326449, 312427]}),
#              170: defaultdict(list, {'view': [161066, 161066, 161066]}),
#              171: defaultdict(list, {'view': [355598]}),
#              172: defaultdict(list,
#                          {'addtocart': [10034, 465522, 465522],
#                           'view': [465522,
#                            465522,
#                            10034,
#                            107943,
#                            79918,
#                            62300,
#                            465522,
#                            202268,
#                            378862,
#                            18519,
#                            27248,
#                            397068,
#                            55710,
#                            374400,
#                            10034,
#                            323030,
#                            254301,
#                            464731,
#                            302810,
#                            464731,
#                            292240,
#                            363106,
#                            412628,
#                            403998,
#                            10034,
#                            10034,
#                            292240,
#                            10034,
#                            464731,
#                            228229,
#                            292240,
#                            253720,
#                            292240]}),
#              173: defaultdict(list, {'view': [417183]}),
#              174: defaultdict(list, {'view': [260546]}),
#              175: defaultdict(list, {'view': [215224]}),
#              176: defaultdict(list, {'view': [64648]}),
#              177: defaultdict(list,
#                          {'addtocart': [6073], 'view': [6073, 6073]}),
#              178: defaultdict(list, {'view': [368559, 368559]}),
#              179: defaultdict(list, {'view': [186746]}),
#              180: defaultdict(list, {'view': [365015]}),
#              181: defaultdict(list, {'view': [119775, 119775]}),
#              182: defaultdict(list, {'view': [316769]}),
#              183: defaultdict(list, {'view': [130897]}),
#              184: defaultdict(list, {'view': [429571, 186095]}),
#              185: defaultdict(list, {'view': [178280]}),
#              186: defaultdict(list,
#                          {'addtocart': [49029], 'view': [49029, 49029]}),
#              187: defaultdict(list, {'view': [369447]}),
#              188: defaultdict(list, {'view': [372243]}),
#              189: defaultdict(list, {'view': [193329]}),
#              190: defaultdict(list, {'view': [444892]}),
#              191: defaultdict(list, {'view': [25828]}),
#              192: defaultdict(list, {'view': [3943]}),
#              193: defaultdict(list, {'view': [366106]}),
#              194: defaultdict(list, {'view': [179991]}),
#              195: defaultdict(list, {'view': [414460]}),
#              196: defaultdict(list, {'view': [286200]}),
#              197: defaultdict(list, {'view': [144066, 383981]}),
#              198: defaultdict(list, {'view': [109919]}),
#              199: defaultdict(list, {'view': [402871]}),
#              200: defaultdict(list, {'view': [340466]}),
#              201: defaultdict(list, {'view': [308557]}),
#              202: defaultdict(list, {'view': [62641]}),
#              203: defaultdict(list, {'view': [21686]}),
#              204: defaultdict(list, {'view': [412676]}),
#              205: defaultdict(list, {'view': [105631, 74614]}),
#              206: defaultdict(list, {'view': [98118]}),
#              207: defaultdict(list, {'view': [99682]}),
#              208: defaultdict(list, {'view': [98425]}),
#              209: defaultdict(list, {'view': [398508]}),
#              210: defaultdict(list, {'view': [29100]}),
#              211: defaultdict(list, {'view': [373907]}),
#              212: defaultdict(list, {'view': [439976, 439976]}),
#              213: defaultdict(list, {'view': [332907, 456393]}),
#              214: defaultdict(list, {'view': [155319]}),
#              215: defaultdict(list, {'view': [452769]}),
#              216: defaultdict(list, {'view': [8140, 8140, 11296]}),
#              217: defaultdict(list, {'view': [403813]}),
#              218: defaultdict(list, {'view': [262477]}),
#              219: defaultdict(list, {'view': [66085, 66085]}),
#              220: defaultdict(list, {'view': [438459]}),
#              221: defaultdict(list, {'view': [285607]}),
#              222: defaultdict(list, {'view': [301719]}),
#              223: defaultdict(list, {'view': [212216]}),
#              224: defaultdict(list,
#                          {'view': [443407,
#                            168697,
#                            443407,
#                            443407,
#                            168697,
#                            168697,
#                            168697,
#                            168697,
#                            168697,
#                            336432,
#                            443407,
#                            443407]}),
#              225: defaultdict(list, {'view': [353737]}),
#              226: defaultdict(list, {'view': [393028]}),
#              227: defaultdict(list, {'view': [462659, 462659]}),
#              228: defaultdict(list, {'view': [50004]}),
#              229: defaultdict(list, {'view': [449071]}),
#              230: defaultdict(list, {'view': [234255, 395845]}),
#              231: defaultdict(list, {'view': [399188, 399188]}),
#              232: defaultdict(list, {'view': [179740]}),
#              233: defaultdict(list, {'view': [128112]}),
#              234: defaultdict(list, {'view': [334920]}),
#              235: defaultdict(list, {'view': [281036]}),
#              236: defaultdict(list, {'view': [365030]}),
#              237: defaultdict(list, {'view': [117905]}),
#              238: defaultdict(list, {'view': [151776]}),
#              239: defaultdict(list, {'view': [345095]}),
#              240: defaultdict(list, {'view': [382538]}),
#              241: defaultdict(list, {'view': [117353]}),
#              242: defaultdict(list, {'view': [192674]}),
#              243: defaultdict(list, {'view': [21243]}),
#              244: defaultdict(list, {'view': [203046]}),
#              245: defaultdict(list, {'view': [261102, 129173]}),
#              246: defaultdict(list, {'view': [117294]}),
#              247: defaultdict(list, {'view': [184953]}),
#              248: defaultdict(list, {'view': [15948, 15948]}),
#              249: defaultdict(list, {'view': [266843]}),
#              250: defaultdict(list, {'view': [86586]}),
#              251: defaultdict(list, {'view': [211393, 325870]}),
#              252: defaultdict(list, {'view': [237539]}),
#              253: defaultdict(list, {'view': [328376, 210318]}),
#              254: defaultdict(list, {'view': [290742, 4564]}),
#              255: defaultdict(list, {'view': [83574, 83574]}),
#              256: defaultdict(list, {'view': [46092]}),
#              257: defaultdict(list, {'view': [163007]}),
#              258: defaultdict(list, {'view': [161650, 358513, 449865]}),
#              259: defaultdict(list, {'view': [403619]}),
#              260: defaultdict(list, {'view': [303960]}),
#              261: defaultdict(list, {'view': [413411]}),
#              262: defaultdict(list, {'view': [257863]}),
#              263: defaultdict(list, {'view': [340027]}),
#              264: defaultdict(list,
#                          {'addtocart': [459835, 161949],
#                           'view': [459835, 161949, 161949]}),
#              265: defaultdict(list, {'view': [351913]}),
#              266: defaultdict(list, {'view': [449033, 39929, 212515, 340315]}),
#              267: defaultdict(list, {'view': [210220]}),
#              268: defaultdict(list, {'view': [335975, 91755]}),
#              269: defaultdict(list, {'view': [265805]}),
#              270: defaultdict(list,
#                          {'view': [286735,
#                            286735,
#                            286735,
#                            286735,
#                            286735,
#                            286735,
#                            286735,
#                            286735,
#                            286735,
#                            286735,
#                            286735,
#                            286735,
#                            286735]}),
#              271: defaultdict(list, {'view': [413166]}),
#              272: defaultdict(list, {'view': [203917, 203917]}),
#              273: defaultdict(list, {'view': [343476]}),
#              274: defaultdict(list, {'view': [121318]}),
#              275: defaultdict(list, {'view': [272261]}),
#              276: defaultdict(list, {'view': [182209]}),
#              277: defaultdict(list, {'view': [254879]}),
#              278: defaultdict(list, {'view': [230915, 458028, 405060]}),
#              279: defaultdict(list, {'view': [49427]}),
#              280: defaultdict(list, {'view': [116299]}),
#              281: defaultdict(list, {'view': [78037]}),
#              282: defaultdict(list, {'view': [251672]}),
#              283: defaultdict(list, {'view': [405124]}),
#              284: defaultdict(list, {'view': [44795]}),
#              285: defaultdict(list, {'view': [227318]}),
#              286: defaultdict(list, {'view': [69081]}),
#              287: defaultdict(list, {'view': [311069, 65273]}),
#              288: defaultdict(list, {'view': [362832]}),
#              289: defaultdict(list, {'view': [442192]}),
#              290: defaultdict(list, {'view': [84172]}),
#              291: defaultdict(list, {'view': [423256]}),
#              292: defaultdict(list, {'view': [401753, 401753]}),
#              293: defaultdict(list, {'view': [58185]}),
#              294: defaultdict(list, {'view': [408179]}),
#              295: defaultdict(list, {'view': [7161, 445817]}),
#              296: defaultdict(list, {'view': [49257, 429775]}),
#              297: defaultdict(list, {'view': [20810]}),
#              298: defaultdict(list, {'view': [291676, 74877, 74877, 244660]}),
#              299: defaultdict(list,
#                          {'addtocart': [149253],
#                           'view': [149253, 416219, 322067, 416219]}),
#              300: defaultdict(list, {'view': [67274]}),
#              301: defaultdict(list, {'view': [209372, 257938]}),
#              302: defaultdict(list, {'addtocart': [463280], 'view': [463280]}),
#              303: defaultdict(list, {'view': [55044]}),
#              304: defaultdict(list, {'view': [191515]}),
#              305: defaultdict(list, {'view': [294141]}),
#              306: defaultdict(list,
#                          {'view': [314073,
#                            118551,
#                            432992,
#                            118551,
#                            432478,
#                            454422,
#                            303828]}),
#              307: defaultdict(list, {'view': [13916, 13916]}),
#              308: defaultdict(list, {'view': [310318]}),
#              309: defaultdict(list, {'view': [66329]}),
#              310: defaultdict(list, {'view': [257863]}),
#              311: defaultdict(list, {'view': [165198]}),
#              312: defaultdict(list, {'view': [431010]}),
#              313: defaultdict(list, {'view': [50302]}),
#              314: defaultdict(list, {'view': [440650]}),
#              315: defaultdict(list, {'view': [34532]}),
#              316: defaultdict(list, {'view': [304162]}),
#              317: defaultdict(list,
#                          {'view': [399221, 399221, 341578, 341578]}),
#              318: defaultdict(list,
#                          {'addtocart': [133814],
#                           'view': [133814,
#                            280029,
#                            184990,
#                            238447,
#                            354233,
#                            214189,
#                            174894]}),
#              319: defaultdict(list, {'view': [386470, 140327]}),
#              320: defaultdict(list, {'view': [328978]}),
#              321: defaultdict(list, {'view': [40178]}),
#              322: defaultdict(list, {'view': [95283]}),
#              323: defaultdict(list, {'view': [329146]}),
#              324: defaultdict(list, {'view': [187946]}),
#              325: defaultdict(list, {'view': [301547]}),
#              326: defaultdict(list, {'view': [221613]}),
#              327: defaultdict(list, {'view': [62973]}),
#              328: defaultdict(list, {'view': [270396]}),
#              329: defaultdict(list, {'view': [445556, 310756, 389566]}),
#              330: defaultdict(list, {'view': [299576]}),
#              331: defaultdict(list, {'view': [304973]}),
#              332: defaultdict(list, {'view': [192227]}),
#              333: defaultdict(list, {'view': [254882, 254882, 254882]}),
#              334: defaultdict(list, {'view': [77293]}),
#              335: defaultdict(list, {'view': [400946]}),
#              336: defaultdict(list, {'view': [365889]}),
#              337: defaultdict(list, {'view': [176881, 176881]}),
#              338: defaultdict(list, {'view': [40124]}),
#              339: defaultdict(list, {'view': [179525]}),
#              340: defaultdict(list, {'view': [21348]}),
#              341: defaultdict(list,
#                          {'view': [99690, 428725, 159419, 112445, 208932]}),
#              342: defaultdict(list, {'view': [347129, 347129]}),
#              343: defaultdict(list, {'view': [309498]}),
#              344: defaultdict(list,
#                          {'view': [271393,
#                            4303,
#                            271393,
#                            4303,
#                            271393,
#                            59211,
#                            4303]}),
#              345: defaultdict(list, {'view': [285603]}),
#              346: defaultdict(list, {'view': [30947]}),
#              347: defaultdict(list, {'view': [199657]}),
#              348: defaultdict(list, {'view': [89143]}),
#              349: defaultdict(list, {'view': [344536]}),
#              350: defaultdict(list, {'view': [238822, 407125]}),
#              351: defaultdict(list,
#                          {'view': [98547,
#                            359368,
#                            433060,
#                            365673,
#                            42444,
#                            98547,
#                            1543,
#                            184465,
#                            412190,
#                            143416,
#                            170751,
#                            216146,
#                            169260,
#                            372248,
#                            395361,
#                            365673,
#                            184465]}),
#              352: defaultdict(list, {'view': [378310]}),
#              353: defaultdict(list, {'view': [86324, 376793, 381636]}),
#              354: defaultdict(list, {'view': [119365]}),
#              355: defaultdict(list, {'view': [8489]}),
#              356: defaultdict(list, {'view': [175555]}),
#              357: defaultdict(list, {'view': [199646, 395497, 417666]}),
#              358: defaultdict(list,
#                          {'view': [159380,
#                            198996,
#                            270291,
#                            167127,
#                            329624,
#                            270291]}),
#              359: defaultdict(list, {'view': [185305]}),
#              360: defaultdict(list, {'view': [460107]}),
#              361: defaultdict(list, {'view': [427633]}),
#              362: defaultdict(list, {'view': [333036]}),
#              363: defaultdict(list,
#                          {'addtocart': [290999],
#                           'view': [290999, 290999, 290999, 290999]}),
#              364: defaultdict(list, {'view': [339661]}),
#              365: defaultdict(list, {'view': [130208]}),
#              366: defaultdict(list, {'view': [274206]}),
#              367: defaultdict(list, {'view': [153714]}),
#              368: defaultdict(list, {'view': [137144]}),
#              369: defaultdict(list, {'view': [32492]}),
#              370: defaultdict(list, {'view': [106801, 216225]}),
#              371: defaultdict(list, {'view': [345348]}),
#              372: defaultdict(list, {'view': [187216]}),
#              373: defaultdict(list, {'view': [258548]}),
#              374: defaultdict(list,
#                          {'view': [167337, 140269, 140269, 158112, 140269]}),
#              375: defaultdict(list, {'view': [437351, 437351]}),
#              376: defaultdict(list, {'view': [49453]}),
#              377: defaultdict(list, {'view': [66184]}),
#              378: defaultdict(list, {'view': [289609]}),
#              379: defaultdict(list,
#                          {'addtocart': [320130], 'view': [356455, 320130]}),
#              380: defaultdict(list, {'view': [69533]}),
#              381: defaultdict(list, {'view': [304537, 465276]}),
#              382: defaultdict(list, {'view': [437659]}),
#              383: defaultdict(list,
#                          {'view': [351798,
#                            450404,
#                            146364,
#                            219718,
#                            246589,
#                            130121,
#                            227688,
#                            117889]}),
#              384: defaultdict(list, {'view': [41766]}),
#              385: defaultdict(list, {'view': [47324]}),
#              386: defaultdict(list, {'view': [373174]}),
#              387: defaultdict(list,
#                          {'view': [11140,
#                            380028,
#                            98830,
#                            11140,
#                            159071,
#                            11140]}),
#              388: defaultdict(list, {'view': [336030]}),
#              389: defaultdict(list, {'view': [393744]}),
#              390: defaultdict(list, {'view': [157033]}),
#              391: defaultdict(list,
#                          {'view': [241555, 241555, 215051, 215051]}),
#              392: defaultdict(list, {'view': [13168]}),
#              393: defaultdict(list, {'view': [181004]}),
#              394: defaultdict(list, {'view': [116681]}),
#              395: defaultdict(list, {'view': [51522]}),
#              396: defaultdict(list, {'view': [459109, 459109]}),
#              397: defaultdict(list, {'view': [191852]}),
#              398: defaultdict(list, {'view': [164160]}),
#              399: defaultdict(list, {'view': [90219, 75018]}),
#              400: defaultdict(list, {'view': [100296]}),
#              401: defaultdict(list, {'view': [460252]}),
#              402: defaultdict(list, {'view': [253175]}),
#              403: defaultdict(list, {'view': [54521]}),
#              404: defaultdict(list, {'view': [298196]}),
#              405: defaultdict(list, {'view': [436781]}),
#              406: defaultdict(list, {'view': [403105]}),
#              407: defaultdict(list, {'view': [404041, 404041]}),
#              408: defaultdict(list, {'view': [263578]}),
#              409: defaultdict(list, {'view': [242126]}),
#              410: defaultdict(list, {'view': [103236, 2110, 28136]}),
#              411: defaultdict(list,
#                          {'view': [305031, 93001, 384758, 77930, 36504]}),
#              412: defaultdict(list, {'view': [409653]}),
#              413: defaultdict(list,
#                          {'view': [447959, 324963, 449246, 133521]}),
#              414: defaultdict(list, {'view': [214887]}),
#              415: defaultdict(list, {'view': [153778]}),
#              416: defaultdict(list,
#                          {'addtocart': [232172],
#                           'view': [232172, 232172, 232172]}),
#              417: defaultdict(list, {'view': [49810]}),
#              418: defaultdict(list, {'view': [270383]}),
#              419: defaultdict(list,
#                          {'addtocart': [19278],
#                           'view': [19278, 426926, 19278, 46391]}),
#              420: defaultdict(list,
#                          {'addtocart': [178480,
#                            395273,
#                            304558,
#                            357779,
#                            395273,
#                            5951,
#                            55239,
#                            187848],
#                           'view': [395273,
#                            178480,
#                            178480,
#                            405266,
#                            395273,
#                            5951]}),
#              421: defaultdict(list, {'view': [4538]}),
#              422: defaultdict(list, {'view': [63451]}),
#              423: defaultdict(list, {'view': [293139]}),
#              424: defaultdict(list, {'view': [15136]}),
#              425: defaultdict(list, {'view': [87074, 87074]}),
#              426: defaultdict(list, {'view': [32515, 346213]}),
#              427: defaultdict(list, {'view': [160467]}),
#              428: defaultdict(list, {'view': [93383]}),
#              429: defaultdict(list, {'view': [336069, 336069, 336069]}),
#              430: defaultdict(list, {'view': [464997]}),
#              431: defaultdict(list, {'view': [53683]}),
#              432: defaultdict(list, {'view': [448601, 448601]}),
#              433: defaultdict(list, {'view': [118633]}),
#              434: defaultdict(list, {'view': [187946]}),
#              435: defaultdict(list, {'view': [121489]}),
#              436: defaultdict(list, {'view': [86596, 200242]}),
#              437: defaultdict(list, {'view': [332816]}),
#              438: defaultdict(list, {'view': [15564]}),
#              439: defaultdict(list, {'view': [308073]}),
#              440: defaultdict(list, {'view': [360964]}),
#              441: defaultdict(list, {'view': [20099]}),
#              442: defaultdict(list, {'view': [4606]}),
#              443: defaultdict(list, {'view': [115323]}),
#              444: defaultdict(list, {'view': [392715, 392715, 392715]}),
#              445: defaultdict(list, {'view': [91105]}),
#              446: defaultdict(list, {'view': [141451]}),
#              447: defaultdict(list, {'view': [62610]}),
#              448: defaultdict(list, {'view': [411854]}),
#              449: defaultdict(list, {'view': [338208, 129611]}),
#              450: defaultdict(list, {'view': [333117]}),
#              451: defaultdict(list, {'view': [427923, 101876]}),
#              452: defaultdict(list, {'view': [235047]}),
#              453: defaultdict(list, {'view': [318468]}),
#              454: defaultdict(list,
#                          {'view': [439343,
#                            439343,
#                            439343,
#                            439343,
#                            439343,
#                            439343,
#                            439343,
#                            439343]}),
#              455: defaultdict(list, {'view': [451942]}),
#              456: defaultdict(list, {'view': [458110]}),
#              457: defaultdict(list, {'view': [228699]}),
#              458: defaultdict(list, {'view': [182419, 182419]}),
#              459: defaultdict(list, {'view': [328751]}),
#              460: defaultdict(list, {'view': [148565]}),
#              461: defaultdict(list, {'view': [462105, 462105]}),
#              462: defaultdict(list, {'view': [227077]}),
#              463: defaultdict(list, {'view': [424896]}),
#              464: defaultdict(list, {'view': [48072, 259884]}),
#              465: defaultdict(list, {'view': [246803]}),
#              466: defaultdict(list, {'view': [267882]}),
#              467: defaultdict(list, {'view': [161899]}),
#              468: defaultdict(list, {'view': [152100, 210161]}),
#              469: defaultdict(list, {'view': [460, 194392]}),
#              470: defaultdict(list, {'view': [116475]}),
#              471: defaultdict(list, {'view': [454848]}),
#              472: defaultdict(list, {'view': [102306]}),
#              473: defaultdict(list, {'view': [326886]}),
#              474: defaultdict(list, {'view': [20981, 415781]}),
#              475: defaultdict(list, {'view': [384302, 368488]}),
#              476: defaultdict(list, {'view': [87853]}),
#              477: defaultdict(list, {'view': [233401, 233401]}),
#              478: defaultdict(list, {'view': [47524]}),
#              479: defaultdict(list, {'view': [309778, 309778]}),
#              480: defaultdict(list, {'view': [296220]}),
#              481: defaultdict(list, {'view': [34356]}),
#              482: defaultdict(list, {'view': [249698, 48030]}),
#              483: defaultdict(list, {'view': [413420]}),
#              484: defaultdict(list,
#                          {'view': [354629,
#                            74871,
#                            385630,
#                            321946,
#                            57214,
#                            129046,
#                            14606,
#                            57610,
#                            452803]}),
#              485: defaultdict(list,
#                          {'view': [248455,
#                            305997,
#                            337798,
#                            208922,
#                            449451,
#                            148103]}),
#              486: defaultdict(list, {'view': [199657]}),
#              487: defaultdict(list, {'view': [378162]}),
#              488: defaultdict(list, {'view': [233072, 50226]}),
#              489: defaultdict(list, {'view': [118549]}),
#              490: defaultdict(list, {'view': [66366]}),
#              491: defaultdict(list, {'view': [89189]}),
#              492: defaultdict(list, {'view': [361088]}),
#              493: defaultdict(list, {'view': [124982]}),
#              494: defaultdict(list, {'view': [193749]}),
#              495: defaultdict(list, {'view': [192090]}),
#              496: defaultdict(list, {'view': [269803, 395920]}),
#              497: defaultdict(list, {'view': [198251]}),
#              498: defaultdict(list, {'view': [427979]}),
#              499: defaultdict(list, {'view': [198067]}),
#              500: defaultdict(list, {'view': [159856]}),
#              501: defaultdict(list, {'view': [284072]}),
#              502: defaultdict(list, {'view': [436230, 2294]}),
#              503: defaultdict(list, {'view': [461939]}),
#              504: defaultdict(list, {'view': [184982]}),
#              505: defaultdict(list, {'view': [328526]}),
#              506: defaultdict(list, {'view': [392302, 357357]}),
#              507: defaultdict(list,
#                          {'view': [197901,
#                            174566,
#                            174566,
#                            174566,
#                            174566,
#                            174566,
#                            174566,
#                            174566]}),
#              508: defaultdict(list, {'view': [161650]}),
#              509: defaultdict(list, {'view': [355994]}),
#              510: defaultdict(list, {'view': [87546]}),
#              511: defaultdict(list, {'view': [151444]}),
#              512: defaultdict(list, {'view': [320130, 334520, 234857]}),
#              513: defaultdict(list, {'view': [255055]}),
#              514: defaultdict(list, {'view': [180519]}),
#              515: defaultdict(list,
#                          {'view': [39207,
#                            256694,
#                            358819,
#                            143316,
#                            358819,
#                            358819,
#                            358819]}),
#              516: defaultdict(list, {'view': [291786]}),
#              517: defaultdict(list, {'view': [198460]}),
#              518: defaultdict(list, {'view': [274206]}),
#              519: defaultdict(list, {'view': [464767, 464767]}),
#              520: defaultdict(list, {'view': [353076]}),
#              521: defaultdict(list, {'view': [67237]}),
#              522: defaultdict(list, {'view': [430550, 199052, 199052]}),
#              523: defaultdict(list, {'view': [63682]}),
#              524: defaultdict(list, {'view': [445351, 445351]}),
#              525: defaultdict(list, {'view': [11279]}),
#              526: defaultdict(list, {'view': [370620]}),
#              527: defaultdict(list, {'view': [399531]}),
#              528: defaultdict(list, {'view': [371579]}),
#              529: defaultdict(list, {'view': [424062]}),
#              530: defaultdict(list, {'view': [87348, 324538]}),
#              531: defaultdict(list, {'view': [445351, 150100]}),
#              532: defaultdict(list, {'view': [404789]}),
#              533: defaultdict(list, {'view': [360664]}),
#              534: defaultdict(list, {'view': [314247]}),
#              535: defaultdict(list, {'view': [252427, 271129]}),
#              536: defaultdict(list, {'view': [117559]}),
#              537: defaultdict(list, {'view': [448722]}),
#              538: defaultdict(list, {'view': [242066]}),
#              539: defaultdict(list,
#                          {'addtocart': [94371, 94371],
#                           'view': [94371, 94371, 94371, 94371]}),
#              540: defaultdict(list, {'view': [208051]}),
#              541: defaultdict(list, {'view': [164242, 164242]}),
#              542: defaultdict(list, {'view': [347912, 123118]}),
#              543: defaultdict(list, {'view': [298196]}),
#              544: defaultdict(list, {'view': [47829]}),
#              545: defaultdict(list, {'view': [92175]}),
#              546: defaultdict(list, {'view': [455937]}),
#              547: defaultdict(list, {'view': [133814]}),
#              548: defaultdict(list, {'view': [446358]}),
#              549: defaultdict(list,
#                          {'view': [39717,
#                            301563,
#                            170500,
#                            322503,
#                            199647,
#                            155550,
#                            16370,
#                            61442,
#                            390881,
#                            369998,
#                            179290,
#                            327109,
#                            4537,
#                            131882,
#                            420528,
#                            266439,
#                            128218]}),
#              550: defaultdict(list, {'view': [323611]}),
#              551: defaultdict(list, {'view': [461081]}),
#              552: defaultdict(list, {'view': [107060]}),
#              553: defaultdict(list, {'view': [104746, 219512]}),
#              554: defaultdict(list, {'view': [75446]}),
#              555: defaultdict(list, {'view': [435812]}),
#              556: defaultdict(list, {'view': [273762, 273762]}),
#              557: defaultdict(list, {'view': [170905]}),
#              558: defaultdict(list, {'view': [304279]}),
#              559: defaultdict(list, {'view': [179483]}),
#              560: defaultdict(list, {'view': [416530]}),
#              561: defaultdict(list, {'view': [432927]}),
#              562: defaultdict(list, {'view': [243554]}),
#              563: defaultdict(list, {'view': [437683]}),
#              564: defaultdict(list, {'view': [25205]}),
#              565: defaultdict(list, {'view': [344723]}),
#              566: defaultdict(list, {'view': [161835]}),
#              567: defaultdict(list, {'view': [319712]}),
#              568: defaultdict(list, {'view': [461119, 461119]}),
#              569: defaultdict(list, {'view': [294282]}),
#              570: defaultdict(list, {'view': [465470, 465470, 254324]}),
#              571: defaultdict(list, {'view': [54892]}),
#              572: defaultdict(list, {'view': [370653]}),
#              573: defaultdict(list, {'view': [55999]}),
#              574: defaultdict(list, {'view': [198021]}),
#              575: defaultdict(list, {'view': [28116]}),
#              576: defaultdict(list,
#                          {'view': [225279, 193182, 193182, 61527, 225279]}),
#              577: defaultdict(list,
#                          {'view': [457464,
#                            457464,
#                            457464,
#                            398634,
#                            398634,
#                            457464,
#                            398634,
#                            398634]}),
#              578: defaultdict(list, {'view': [350019]}),
#              579: defaultdict(list, {'view': [107017, 188381]}),
#              580: defaultdict(list, {'view': [216749, 216749]}),
#              581: defaultdict(list, {'view': [388097]}),
#              582: defaultdict(list, {'view': [1152]}),
#              583: defaultdict(list, {'view': [53108]}),
#              584: defaultdict(list, {'view': [23465, 23465]}),
#              585: defaultdict(list, {'view': [130951]}),
#              586: defaultdict(list, {'view': [56630, 107219, 107219, 153782]}),
#              587: defaultdict(list, {'view': [82444]}),
#              588: defaultdict(list, {'addtocart': [250345], 'view': [250345]}),
#              589: defaultdict(list, {'view': [340375, 340375, 120411]}),
#              590: defaultdict(list, {'view': [29015]}),
#              591: defaultdict(list, {'view': [5351]}),
#              592: defaultdict(list, {'view': [343214]}),
#              593: defaultdict(list, {'view': [188183]}),
#              594: defaultdict(list, {'view': [432218]}),
#              595: defaultdict(list, {'view': [185001]}),
#              596: defaultdict(list, {'view': [70026, 70026]}),
#              597: defaultdict(list, {'view': [391992]}),
#              598: defaultdict(list, {'view': [305888]}),
#              599: defaultdict(list, {'view': [348093]}),
#              600: defaultdict(list, {'view': [305385]}),
#              601: defaultdict(list, {'view': [55121, 55121]}),
#              602: defaultdict(list, {'view': [440561]}),
#              603: defaultdict(list, {'view': [464821]}),
#              604: defaultdict(list,
#                          {'view': [87869,
#                            366667,
#                            80096,
#                            87869,
#                            87869,
#                            87869,
#                            87869,
#                            87869,
#                            87869,
#                            87869,
#                            242771,
#                            124896,
#                            87869,
#                            167395,
#                            87869]}),
#              605: defaultdict(list, {'view': [165198, 165198, 197901]}),
#              606: defaultdict(list, {'view': [308353]}),
#              607: defaultdict(list, {'view': [155451]}),
#              608: defaultdict(list, {'view': [234255]}),
#              609: defaultdict(list, {'view': [201434, 201434]}),
#              610: defaultdict(list, {'view': [73249]}),
#              611: defaultdict(list, {'view': [69057, 334591]}),
#              612: defaultdict(list, {'view': [203642]}),
#              613: defaultdict(list, {'view': [427366]}),
#              614: defaultdict(list, {'view': [122867]}),
# ...
#              780: defaultdict(list, {'view': [194010]}),
#              781: defaultdict(list, {'view': [347303]}),
#              782: defaultdict(list, {'view': [166205]}),
#              783: defaultdict(list,
#                          {'view': [242188, 242188, 263099, 183095]}),
#              784: defaultdict(list, {'view': [97291]}),
#              785: defaultdict(list, {'view': [436929]}),
#              786: defaultdict(list, {'view': [298023]}),
#              787: defaultdict(list, {'view': [446197]}),
#              788: defaultdict(list, {'view': [112919]}),
#              789: defaultdict(list, {'view': [139256]}),
#              790: defaultdict(list, {'view': [231582]}),
#              791: defaultdict(list, {'view': [363363]}),
#              792: defaultdict(list, {'view': [207923]}),
#              793: defaultdict(list, {'view': [192569]}),
#              794: defaultdict(list, {'view': [316653]}),
#              795: defaultdict(list,
#                          {'addtocart': [207825],
#                           'view': [225123,
#                            262006,
#                            155485,
#                            235009,
#                            131036,
#                            180905,
#                            180905,
#                            154681,
#                            180905,
#                            180905,
#                            180905,
#                            180905,
#                            180905,
#                            180905]}),
#              796: defaultdict(list, {'view': [283083]}),
#              797: defaultdict(list, {'view': [32407]}),
#              798: defaultdict(list, {'view': [192792]}),
#              799: defaultdict(list, {'view': [157322]}),
#              800: defaultdict(list, {'view': [271811]}),
#              801: defaultdict(list, {'view': [7943]}),
#              802: defaultdict(list, {'view': [174658]}),
#              803: defaultdict(list, {'view': [323934]}),
#              804: defaultdict(list, {'view': [432749]}),
#              805: defaultdict(list, {'view': [414489, 412254]}),
#              806: defaultdict(list, {'view': [99615]}),
#              807: defaultdict(list, {'view': [156878, 246117]}),
#              808: defaultdict(list, {'view': [311664, 139401]}),
#              809: defaultdict(list, {'view': [328350]}),
#              810: defaultdict(list, {'view': [40930]}),
#              811: defaultdict(list, {'view': [315876]}),
#              812: defaultdict(list, {'view': [51542]}),
#              813: defaultdict(list, {'view': [300881]}),
#              814: defaultdict(list, {'view': [175574, 387377]}),
#              815: defaultdict(list, {'view': [299123]}),
#              816: defaultdict(list, {'view': [425639]}),
#              817: defaultdict(list, {'view': [306524]}),
#              818: defaultdict(list, {'view': [351820]}),
#              819: defaultdict(list, {'view': [389358]}),
#              820: defaultdict(list, {'view': [165169]}),
#              821: defaultdict(list, {'view': [191334]}),
#              822: defaultdict(list, {'view': [273936]}),
#              823: defaultdict(list, {'view': [34982]}),
#              824: defaultdict(list, {'view': [428827, 428827, 428827]}),
#              825: defaultdict(list, {'view': [98861]}),
#              826: defaultdict(list, {'view': [288195, 288195]}),
#              827: defaultdict(list, {'view': [457471]}),
#              828: defaultdict(list, {'view': [348294]}),
#              829: defaultdict(list, {'view': [444828]}),
#              830: defaultdict(list, {'view': [370482]}),
#              831: defaultdict(list, {'view': [88703]}),
#              832: defaultdict(list, {'view': [93202]}),
#              833: defaultdict(list, {'view': [315543]}),
#              834: defaultdict(list, {'view': [244577]}),
#              835: defaultdict(list, {'view': [409804]}),
#              836: defaultdict(list, {'view': [185831]}),
#              837: defaultdict(list, {'view': [88749]}),
#              838: defaultdict(list, {'view': [90417]}),
#              839: defaultdict(list, {'view': [36958]}),
#              840: defaultdict(list, {'view': [424173]}),
#              841: defaultdict(list, {'view': [406039]}),
#              842: defaultdict(list, {'view': [288474]}),
#              843: defaultdict(list, {'view': [101197]}),
#              844: defaultdict(list, {'view': [210373]}),
#              845: defaultdict(list,
#                          {'addtocart': [351530],
#                           'view': [351530, 351530, 351530, 333588]}),
#              846: defaultdict(list, {'view': [448044]}),
#              847: defaultdict(list, {'view': [251265]}),
#              848: defaultdict(list, {'view': [46924, 256695, 256695]}),
#              849: defaultdict(list, {'view': [441836]}),
#              850: defaultdict(list, {'view': [434574]}),
#              851: defaultdict(list, {'view': [218215]}),
#              852: defaultdict(list, {'view': [263146]}),
#              853: defaultdict(list, {'view': [442384, 442384]}),
#              854: defaultdict(list, {'view': [429233]}),
#              855: defaultdict(list, {'view': [69551, 201850]}),
#              856: defaultdict(list, {'view': [191016, 60954]}),
#              857: defaultdict(list, {'view': [427709]}),
#              858: defaultdict(list, {'view': [406116]}),
#              859: defaultdict(list,
#                          {'view': [192409,
#                            232610,
#                            257040,
#                            257575,
#                            451386,
#                            460228]}),
#              860: defaultdict(list, {'view': [119743, 119743, 119743]}),
#              861: defaultdict(list, {'view': [79959]}),
#              862: defaultdict(list, {'view': [455159]}),
#              863: defaultdict(list, {'view': [388783]}),
#              864: defaultdict(list, {'view': [316894]}),
#              865: defaultdict(list, {'view': [175909]}),
#              866: defaultdict(list, {'view': [28144, 303833, 303833]}),
#              867: defaultdict(list, {'view': [29580]}),
#              868: defaultdict(list, {'view': [308538]}),
#              869: defaultdict(list, {'view': [179714]}),
#              870: defaultdict(list, {'view': [442418]}),
#              871: defaultdict(list, {'view': [301657]}),
#              872: defaultdict(list, {'view': [52837]}),
#              873: defaultdict(list, {'view': [394821]}),
#              874: defaultdict(list, {'view': [236155]}),
#              875: defaultdict(list, {'view': [329848]}),
#              876: defaultdict(list, {'view': [155056]}),
#              877: defaultdict(list,
#                          {'view': [83126,
#                            83126,
#                            83126,
#                            280939,
#                            6908,
#                            83126,
#                            330713,
#                            83126,
#                            83126,
#                            83126,
#                            83126]}),
#              878: defaultdict(list,
#                          {'addtocart': [283916],
#                           'view': [268883,
#                            2270,
#                            420960,
#                            268883,
#                            283916,
#                            110374,
#                            110374,
#                            320566,
#                            283916,
#                            268883,
#                            101288,
#                            2270]}),
#              879: defaultdict(list, {'view': [84773]}),
#              880: defaultdict(list, {'view': [86270]}),
#              881: defaultdict(list, {'view': [194729]}),
#              882: defaultdict(list, {'view': [464731]}),
#              883: defaultdict(list, {'view': [249610]}),
#              884: defaultdict(list, {'view': [264947]}),
#              885: defaultdict(list, {'view': [449130]}),
#              886: defaultdict(list, {'view': [81641]}),
#              887: defaultdict(list, {'view': [86316]}),
#              888: defaultdict(list, {'view': [100279]}),
#              889: defaultdict(list, {'view': [361734, 179725, 223820]}),
#              890: defaultdict(list, {'view': [122380, 39560, 31970]}),
#              891: defaultdict(list, {'view': [129356]}),
#              892: defaultdict(list, {'view': [38582]}),
#              893: defaultdict(list, {'view': [64733]}),
#              894: defaultdict(list,
#                          {'view': [116359, 116359, 116359, 43241, 116359]}),
#              895: defaultdict(list, {'view': [435796]}),
#              896: defaultdict(list, {'view': [462682]}),
#              897: defaultdict(list, {'view': [274459]}),
#              898: defaultdict(list, {'view': [261013, 134858]}),
#              899: defaultdict(list, {'view': [197642]}),
#              900: defaultdict(list, {'view': [191016]}),
#              901: defaultdict(list, {'view': [85510]}),
#              902: defaultdict(list, {'view': [419371, 419371, 419371]}),
#              903: defaultdict(list, {'view': [401285, 250015]}),
#              904: defaultdict(list, {'addtocart': [267461], 'view': [267461]}),
#              905: defaultdict(list, {'view': [349659]}),
#              906: defaultdict(list, {'view': [99241]}),
#              907: defaultdict(list, {'view': [437569]}),
#              908: defaultdict(list, {'view': [401716, 401716, 401716]}),
#              909: defaultdict(list, {'view': [402684]}),
#              910: defaultdict(list, {'view': [92814, 92814, 461520]}),
#              911: defaultdict(list, {'view': [212767, 212767, 207430]}),
#              912: defaultdict(list, {'view': [217650]}),
#              913: defaultdict(list, {'view': [429503]}),
#              914: defaultdict(list, {'addtocart': [382946], 'view': [382946]}),
#              915: defaultdict(list, {'view': [423362]}),
#              916: defaultdict(list, {'view': [101288, 124941]}),
#              917: defaultdict(list, {'view': [412416, 396254]}),
#              918: defaultdict(list,
#                          {'addtocart': [222888, 222888],
#                           'view': [97307, 97307]}),
#              919: defaultdict(list, {'view': [308384]}),
#              920: defaultdict(list, {'view': [325928]}),
#              921: defaultdict(list,
#                          {'view': [175245,
#                            22436,
#                            175245,
#                            245510,
#                            299038,
#                            175245]}),
#              922: defaultdict(list, {'view': [110405, 110405, 110405]}),
#              923: defaultdict(list,
#                          {'view': [389306, 203917, 177009, 466118, 168452]}),
#              924: defaultdict(list, {'view': [20594]}),
#              925: defaultdict(list,
#                          {'view': [328025,
#                            328025,
#                            398156,
#                            328025,
#                            88037,
#                            123287]}),
#              926: defaultdict(list, {'view': [374400, 278094]}),
#              927: defaultdict(list, {'view': [134519]}),
#              928: defaultdict(list, {'view': [247491]}),
#              929: defaultdict(list, {'view': [31954]}),
#              930: defaultdict(list, {'view': [147110]}),
#              931: defaultdict(list, {'view': [177982]}),
#              932: defaultdict(list, {'view': [287860, 287860, 287860]}),
#              933: defaultdict(list, {'view': [357891]}),
#              934: defaultdict(list, {'view': [370653, 370653]}),
#              935: defaultdict(list, {'view': [53302]}),
#              936: defaultdict(list, {'view': [236975]}),
#              937: defaultdict(list, {'view': [309889]}),
#              938: defaultdict(list, {'view': [187946]}),
#              939: defaultdict(list, {'view': [20719]}),
#              940: defaultdict(list, {'view': [447360, 303341]}),
#              941: defaultdict(list, {'view': [117283]}),
#              942: defaultdict(list, {'view': [455141, 455141, 455141]}),
#              943: defaultdict(list, {'view': [146097]}),
#              944: defaultdict(list, {'view': [377972, 213747]}),
#              945: defaultdict(list, {'view': [373665, 428002]}),
#              946: defaultdict(list, {'view': [98057]}),
#              947: defaultdict(list, {'view': [335975]}),
#              948: defaultdict(list, {'view': [321253]}),
#              949: defaultdict(list, {'view': [267882]}),
#              950: defaultdict(list, {'view': [446039]}),
#              951: defaultdict(list, {'view': [51118]}),
#              952: defaultdict(list, {'view': [410086]}),
#              953: defaultdict(list, {'view': [126332]}),
#              954: defaultdict(list, {'view': [466735]}),
#              955: defaultdict(list, {'view': [35322]}),
#              956: defaultdict(list, {'view': [151444]}),
#              957: defaultdict(list, {'view': [422559]}),
#              958: defaultdict(list, {'view': [336756]}),
#              959: defaultdict(list, {'view': [392929]}),
#              960: defaultdict(list, {'view': [143933]}),
#              961: defaultdict(list, {'view': [282665]}),
#              962: defaultdict(list, {'view': [432992, 234808]}),
#              963: defaultdict(list, {'view': [345723]}),
#              964: defaultdict(list,
#                          {'addtocart': [430113],
#                           'view': [430113,
#                            430113,
#                            430113,
#                            430113,
#                            430113,
#                            430113]}),
#              965: defaultdict(list, {'view': [226597]}),
#              966: defaultdict(list, {'view': [60057]}),
#              967: defaultdict(list, {'view': [250390]}),
#              968: defaultdict(list, {'view': [374493]}),
#              969: defaultdict(list, {'view': [122676]}),
#              970: defaultdict(list,
#                          {'view': [144131,
#                            308851,
#                            259384,
#                            144131,
#                            144131,
#                            42542]}),
#              971: defaultdict(list, {'view': [157950]}),
#              972: defaultdict(list, {'view': [188171, 188171]}),
#              973: defaultdict(list, {'view': [461686]}),
#              974: defaultdict(list, {'view': [277079]}),
#              975: defaultdict(list, {'view': [454640]}),
#              976: defaultdict(list, {'view': [280375]}),
#              977: defaultdict(list, {'view': [236088]}),
#              978: defaultdict(list, {'view': [447285]}),
#              979: defaultdict(list, {'view': [57284]}),
#              980: defaultdict(list, {'view': [230602]}),
#              981: defaultdict(list, {'view': [103816]}),
#              982: defaultdict(list, {'view': [133814, 29196, 46232]}),
#              983: defaultdict(list,
#                          {'view': [394678,
#                            181242,
#                            230785,
#                            98063,
#                            429571,
#                            459664,
#                            429571]}),
#              984: defaultdict(list, {'view': [83805]}),
#              985: defaultdict(list, {'view': [175201]}),
#              986: defaultdict(list, {'view': [312202]}),
#              987: defaultdict(list, {'view': [184879]}),
#              988: defaultdict(list, {'view': [33661]}),
#              989: defaultdict(list, {'view': [54376, 331209, 339531]}),
#              990: defaultdict(list, {'view': [338630]}),
#              991: defaultdict(list, {'view': [388833]}),
#              992: defaultdict(list, {'view': [206467, 298883]}),
#              993: defaultdict(list, {'view': [51467, 435796]}),
#              994: defaultdict(list, {'view': [447638]}),
#              995: defaultdict(list, {'view': [8320, 8320]}),
#              996: defaultdict(list, {'view': [385260]}),
#              997: defaultdict(list, {'view': [372133]}),
#              998: defaultdict(list, {'view': [344982]}),
#              999: defaultdict(list, {'view': [13707]}),
#              ...})
